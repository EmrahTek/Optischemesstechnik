# %%
import numpy as np

l = 1.00
T = 2.0
g = 4*np.pi**2*1 /(T**2)
print("Erdbeschleunigung: ", g)
# Out:
# Erdbeschleunigung:  9.869604401089358

# %%
from uncertainties import ufloat
l = ufloat(1.00, 0.05) # l = 1.00+/-0.05
T = ufloat(2.0, 0.2)
# T = 2.0+/-0.2
g = 4 * np.pi**2 * l / (T**2)
print("Erdbeschleunigung:", g)

print(f"Erdbeschleunigung: {g:.3f}")
# Out:
# Erdbeschleunigung: 9.9+/-2.0
# Erdbeschleunigung: 9.870+/-2.035
